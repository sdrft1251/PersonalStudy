# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
# %matplotlib inline
import matplotlib
matplotlib.rc('axes', unicode_minus=False)
import lightgbm as lgb

# %% [markdown]
# # Data Load

# %%
train_df = pd.read_csv("./data/train.csv")
print(train_df.shape)
# Out:
# (2952, 15)

# %% [markdown]
# # Modeling

# %%
print("Before : ", train_df.shape)
train_df = train_df[np.logical_and(train_df["도보 10분거리 내 지하철역 수(환승노선 수 반영)"].notnull(),train_df["도보 10분거리 내 버스정류장 수"].notnull())]
print("After : ", train_df.shape)


area_list = list(train_df["지역"].unique())
supp_list = list(train_df["공급유형"].unique())
qual_list = list(train_df["자격유형"].unique())


def return_preprocessed_dataset(df, train_set=True, col_select=[]):
    # 초기화 변수
    inputs_arr = []
    ap_idx_arr = []
    targets_arr = []
    for_multiple = []
    
    for ap_code in df["단지코드"].unique():
        # 빈 array 만들기
        inputs_ = np.zeros(6+len(supp_list)+len(qual_list)+5)
        
        # 인덱스 및 데이터프레임 추려내기
        ap_idx_arr.append(ap_code)
        sample_df = df[df["단지코드"]==ap_code].reset_index(drop=True)
        sample_df.fillna(0, inplace=True)
        
        # For Result
        for_multiple.append(sample_df["총세대수"].values[0] - sample_df["공가수"].values[0])
        
        # Train Set일 경우 target 생성
        if train_set:
            target = sample_df["등록차량수"].values[0]
            targets_arr.append(target)
            
        ### --- Input용 데이터 처리 시작
        tot_house_num = sample_df["전용면적별세대수"].sum()
        tot_house_num_add_install = sample_df["총세대수"].values[0]
        space = 0
        lent_amount = 0
        lent_fee = 0
        
        # 데이터 대입
        inputs_[0] = sample_df[sample_df["임대건물구분"]=="아파트"]["전용면적별세대수"].sum() / tot_house_num_add_install
        inputs_[1] = sample_df[sample_df["임대건물구분"]=="상가"]["전용면적별세대수"].sum() / tot_house_num_add_install
        inputs_[2] = (tot_house_num_add_install-tot_house_num) / tot_house_num_add_install
        inputs_[3] = area_list.index(sample_df["지역"].values[0])
        inputs_[4] = sample_df["도보 10분거리 내 지하철역 수(환승노선 수 반영)"].values[0]
        inputs_[5] = sample_df["도보 10분거리 내 버스정류장 수"].values[0]
        
        for row_idx in range(sample_df.shape[0]):
            row_samp = sample_df.iloc[row_idx].copy()
            inputs_[supp_list.index(row_samp["공급유형"])+6] +=  row_samp["전용면적별세대수"]/tot_house_num
            if row_samp["자격유형"] == 0:
                inputs_[qual_list.index("O")+len(supp_list)+6] +=  row_samp["전용면적별세대수"]/tot_house_num
            else:
                inputs_[qual_list.index(row_samp["자격유형"])+len(supp_list)+6] +=  row_samp["전용면적별세대수"]/tot_house_num
            space += row_samp["전용면적"] * row_samp["전용면적별세대수"]

            if row_samp["임대보증금"] == "-":
                lent_amount += 0
            else:
                lent_amount += (float(row_samp["임대보증금"])/1000) * row_samp["전용면적별세대수"]
            if row_samp["임대료"] == "-":
                lent_fee += 0
            else:
                lent_fee += (float(row_samp["임대료"])/1000) * row_samp["전용면적별세대수"]
                
        space = space/tot_house_num
        lent_amount = (lent_amount/tot_house_num)*1000
        lent_fee = (lent_fee/tot_house_num)*1000
        inputs_[-5] = space
        inputs_[-4] = lent_amount
        inputs_[-3] = lent_fee
        inputs_[-2] = sample_df["총세대수"].values[0] - sample_df["공가수"].values[0]
        inputs_[-1] = sample_df["단지내주차면수"].values[0]

        inputs_arr.append(inputs_)
    
    targets_arr = np.array(targets_arr)
    inputs_arr = np.array(inputs_arr)
    ap_idx_arr = np.array(ap_idx_arr)
    for_multiple = np.array(for_multiple)
    
    print(targets_arr.shape, inputs_arr.shape, ap_idx_arr.shape, for_multiple.shape)
    
    cols = ["apart_rate", "market_rate", "install_rate", "area", "metro", "bus"] + supp_list + qual_list + ["space", "lent_amount", "lent_fee", "house_hold_num","pos_park"]

    inputs_df = pd.DataFrame(inputs_arr, columns = cols)
    
    if len(col_select)>0:
        inputs_df = inputs_df[col_select]
    
    print(inputs_df.info())
    
    return inputs_df, targets_arr, ap_idx_arr, for_multiple
# Out:
# Before :  (2952, 15)
# After :  (2741, 15)

# %%
print("Start Train df preprocessing")
train_inputs, train_targets, train_ap_idx, train_for_multiple = return_preprocessed_dataset(df=train_df, train_set=True)

print()
print("Start Test df preprocessing")
test_df = pd.read_csv("./data/test.csv")
print(test_df.shape)
test_inputs, test_targets, test_ap_idx, test_for_multiple = return_preprocessed_dataset(df=test_df, train_set=False)
# Out:
# Start Train df preprocessing
# (403,) (403, 35) (403,) (403,)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   apart_rate      403 non-null    float64
#  1   market_rate     403 non-null    float64
#  2   install_rate    403 non-null    float64
#  3   area            403 non-null    float64
#  4   metro           403 non-null    float64
#  5   bus             403 non-null    float64
#  6   국민임대            403 non-null    float64
#  7   공공임대(50년)       403 non-null    float64
#  8   영구임대            403 non-null    float64
#  9   임대상가            403 non-null    float64
#  10  공공임대(10년)       403 non-null    float64
#  11  공공임대(분납)        403 non-null    float64
#  12  장기전세            403 non-null    float64
#  13  행복주택            403 non-null    float64
#  14  공공임대(5년)        403 non-null    float64
#  15  A               403 non-null    float64
#  16  B               403 non-null    float64
#  17  C               403 non-null    float64
#  18  D               403 non-null    float64
#  19  F               403 non-null    float64
#  20  E               403 non-null    float64
#  21  G               403 non-null    float64
#  22  H               403 non-null    float64
#  23  I               403 non-null    float64
#  24  J               403 non-null    float64
#  25  K               403 non-null    float64
#  26  L               403 non-null    float64
#  27  M               403 non-null    float64
#  28  N               403 non-null    float64
#  29  O               403 non-null    float64
#  30  space           403 non-null    float64
#  31  lent_amount     403 non-null    float64
#  32  lent_fee        403 non-null    float64
#  33  house_hold_num  403 non-null    float64
#  34  pos_park        403 non-null    float64
# dtypes: float64(35)
# memory usage: 110.3 KB
# None
#
# Start Test df preprocessing
# (1022, 14)
# (0,) (150, 35) (150,) (150,)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   apart_rate      150 non-null    float64
#  1   market_rate     150 non-null    float64
#  2   install_rate    150 non-null    float64
#  3   area            150 non-null    float64
#  4   metro           150 non-null    float64
#  5   bus             150 non-null    float64
#  6   국민임대            150 non-null    float64
#  7   공공임대(50년)       150 non-null    float64
#  8   영구임대            150 non-null    float64
#  9   임대상가            150 non-null    float64
#  10  공공임대(10년)       150 non-null    float64
#  11  공공임대(분납)        150 non-null    float64
#  12  장기전세            150 non-null    float64
#  13  행복주택            150 non-null    float64
#  14  공공임대(5년)        150 non-null    float64
#  15  A               150 non-null    float64
#  16  B               150 non-null    float64
#  17  C               150 non-null    float64
#  18  D               150 non-null    float64
#  19  F               150 non-null    float64
#  20  E               150 non-null    float64
#  21  G               150 non-null    float64
#  22  H               150 non-null    float64
#  23  I               150 non-null    float64
#  24  J               150 non-null    float64
#  25  K               150 non-null    float64
#  26  L               150 non-null    float64
#  27  M               150 non-null    float64
#  28  N               150 non-null    float64
#  29  O               150 non-null    float64
#  30  space           150 non-null    float64
#  31  lent_amount     150 non-null    float64
#  32  lent_fee        150 non-null    float64
#  33  house_hold_num  150 non-null    float64
#  34  pos_park        150 non-null    float64
# dtypes: float64(35)
# memory usage: 41.1 KB
# None

# %%
train_data_idx = np.random.permutation(len(train_targets))
test_set_rate = 0.2
train_set_rate = 1-test_set_rate

for_train_idx = train_data_idx[:int(len(train_data_idx)*train_set_rate)]
for_valid_idx = train_data_idx[int(len(train_data_idx)*train_set_rate):]

x_train = train_inputs.iloc[for_train_idx]
y_train = train_targets[for_train_idx]
train_part_ap_idx = train_ap_idx[for_train_idx]
train_part_multiple = train_for_multiple[for_train_idx]

x_valid = train_inputs.iloc[for_valid_idx]
y_valid = train_targets[for_valid_idx]
valid_part_ap_idx = train_ap_idx[for_valid_idx]
valid_part_multiple = train_for_multiple[for_valid_idx]

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (322, 35) (322,)
# (81, 35) (81,)

# %%
def make_arr_for_norm(train_df, col_need):
    max_for_reg = np.ones(train_df.shape[1])
    min_for_reg = np.zeros(train_df.shape[1])
    
    for idx, val, in enumerate(train_df.columns):
        if val in col_need:
            max_for_reg[idx] = train_df[val].values.max()
            min_for_reg[idx] = train_df[val].values.min()
    return max_for_reg, min_for_reg

max_for_reg, min_for_reg = make_arr_for_norm(train_df=x_train, col_need=["metro","bus","space","lent_amount","lent_fee"])

x_train_norm = (x_train-min_for_reg) / (max_for_reg-min_for_reg)
x_valid_norm = (x_valid-min_for_reg) / (max_for_reg-min_for_reg)

# %%
d_train = lgb.Dataset(x_train_norm, label=y_train)
d_valid = lgb.Dataset(x_valid_norm, label=y_valid)
watchlist = [d_valid]

params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'l1',
    'max_depth': -1,
    'early_stopping_rounds' : 20,
    'learning_rate': 0.01,
    'verbose': 0
    }
n_estimators = 1000


model_use = lgb.train(params, d_train, n_estimators, watchlist, categorical_feature=["area"], verbose_eval=1)

train_preds = model_use.predict(x_train_norm)
valid_preds = model_use.predict(x_valid_norm)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's l1: 134.793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's l1: 134.816
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's l1: 134.796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's l1: 134.819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's l1: 134.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's l1: 134.794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's l1: 134.775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's l1: 134.713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's l1: 134.699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's l1: 134.694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's l1: 134.676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's l1: 134.619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's l1: 134.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's l1: 134.589
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's l1: 134.621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's l1: 134.654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's l1: 134.63
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's l1: 134.565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's l1: 134.578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's l1: 134.611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's l1: 134.648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's l1: 134.627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's l1: 134.605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's l1: 134.642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's l1: 134.676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's l1: 134.668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's l1: 134.69
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's l1: 134.643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's l1: 134.66
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's l1: 134.706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's l1: 134.656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's l1: 134.685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's l1: 134.636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's l1: 134.667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's l1: 134.62
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's l1: 134.609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's l1: 134.561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's l1: 134.565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's l1: 134.641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's l1: 134.664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's l1: 134.652
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's l1: 134.605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's l1: 134.595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's l1: 134.669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's l1: 134.706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's l1: 134.695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's l1: 134.649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's l1: 134.655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's l1: 134.728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's l1: 134.757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's l1: 134.713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's l1: 134.704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's l1: 134.775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's l1: 134.767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's l1: 134.758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's l1: 134.75
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's l1: 134.78
# Early stopping, best iteration is:
# [288]	valid_0's l1: 134.561
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1706: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['area']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))

# %%
train_preds_transformed = train_preds
valid_preds_transformed = valid_preds

# %%
train_answer = []
for ap_code in train_part_ap_idx:
    ans = train_df[train_df["단지코드"]==ap_code]["등록차량수"].values[0]
    train_answer.append(ans)
train_answer = np.array(train_answer)

valid_answer = []
for ap_code in valid_part_ap_idx:
    ans = train_df[train_df["단지코드"]==ap_code]["등록차량수"].values[0]
    valid_answer.append(ans)
valid_answer = np.array(valid_answer)

# %%
train_mae = sum(abs(train_preds_transformed - train_answer)) / len(train_preds_transformed)
valid_mae = sum(abs(valid_preds_transformed - valid_answer)) / len(valid_preds_transformed)

print("MAE of Train : {} / Valid : {}".format(train_mae, valid_mae))
# Out:
# MAE of Train : 93.84827801854229 / Valid : 134.561062502551

# %% [markdown]
# # Input Test set

# %%
test_input_norm = (test_inputs-min_for_reg) / (max_for_reg-min_for_reg)

test_preds = model_use.predict(test_input_norm)
test_preds_transformed = test_preds

# %%
for_sub = pd.read_csv("./data/sample_submission.csv")
for_sub
# Out:
#       code  num
# 0    C1072    0
# 1    C1128    0
# 2    C1456    0
# 3    C1840    0
# 4    C1332    0
# ..     ...  ...
# 145  C2456    0
# 146  C1266    0
# 147  C2152    0
# 148  C1267    0
# 149  C2189    0
#
# [150 rows x 2 columns]

# %%
def transform_sub(raw):
    val = test_preds_transformed[test_ap_idx==raw.code]
    return val[0]

for_sub_copy = for_sub.copy()
for_sub_copy['num'] = for_sub.apply(transform_sub, axis=1)

# %%
for_sub_copy
# Out:
#       code          num
# 0    C1072   745.484666
# 1    C1128  1349.230309
# 2    C1456   609.666215
# 3    C1840   530.904965
# 4    C1332  1270.306471
# ..     ...          ...
# 145  C2456   233.833345
# 146  C1266   441.780034
# 147  C2152   128.942066
# 148  C1267   382.482773
# 149  C2189   280.383086
#
# [150 rows x 2 columns]

# %%
for_sub_copy.to_csv("./Result/model_v01_04.csv", index=False)

# %% [markdown]
# # Result Analysis

# %%
import shap
import skimage

# %%
explainer = shap.TreeExplainer(model_use)
shap_values = explainer.shap_values(x_valid_norm)

# %%
shap.summary_plot(shap_values, x_valid_norm)

# %%
for col in x_valid_norm.columns:
    print(col)
    shap.dependence_plot(col, shap_values, x_valid_norm)
    plt.show()
# Out:
# apart_rate
# market_rate
# install_rate
# area
# metro
# bus
# 국민임대
# 공공임대(50년)
# 영구임대
# 임대상가
# 공공임대(10년)
# 공공임대(분납)
# 장기전세
# 행복주택
# 공공임대(5년)
# A
# B
# C
# D
# F
# E
# G
# H
# I
# J
# K
# L
# M
# N
# O
# space
# lent_amount
# lent_fee
# house_hold_num
# pos_park

# %%
explainer = shap.TreeExplainer(model_use)
shap_values = explainer.shap_values(x_train_norm)
shap.summary_plot(shap_values, x_train_norm)

# %%
for col in x_train_norm.columns:
    print(col)
    shap.dependence_plot(col, shap_values, x_train_norm)
    plt.show()
# Out:
# apart_rate
# market_rate
# install_rate
# area
# metro
# bus
# 국민임대
# 공공임대(50년)
# 영구임대
# 임대상가
# 공공임대(10년)
# 공공임대(분납)
# 장기전세
# 행복주택
# 공공임대(5년)
# A
# B
# C
# D
# F
# E
# G
# H
# I
# J
# K
# L
# M
# N
# O
# space
# lent_amount
# lent_fee
# house_hold_num
# pos_park
